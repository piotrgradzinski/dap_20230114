# %%
import pandas as pd

# %% [markdown]
# ## Reading data from files
#
# - https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html
#
# What we need to do when creating a dataframe:
# - do we have a coulmn that can be an index for the data frame
# - do we have any columns that contain dates so we can parse them properly into proper data type

# %%
url = 'https://raw.githubusercontent.com/piotrgradzinski/dap_20230114/main/day_6_pgg/emps.csv'
emps = pd.read_csv(url, sep=';', encoding='utf-8', index_col='employee_id', parse_dates=['hire_date'])
emps
# Out:
#             first_name last_name                        job_title  salary  \
# employee_id
# 100             Steven      King                        President   24000
# 101              Neena   Kochhar    Administration Vice President   17000
# 102                Lex   De Haan    Administration Vice President   17000
# 103          Alexander    Hunold                       Programmer    9000
# 104              Bruce     Ernst                       Programmer    6000
# ...                ...       ...                              ...     ...
# 202                Pat       Fay         Marketing Representative    6000
# 203              Susan    Mavris   Human Resources Representative    6500
# 204            Hermann      Baer  Public Relations Representative   10000
# 205            Shelley   Higgins               Accounting Manager   12000
# 206            William     Gietz                Public Accountant    8300
#
#              hire_date   department_name                address postal_code  \
# employee_id
# 100         1997-06-17         Executive        2004 Charade Rd       98199
# 101         1999-09-21         Executive        2004 Charade Rd       98199
# 102         2003-01-13         Executive        2004 Charade Rd       98199
# 103         2000-01-03                IT    2014 Jabberwocky Rd       26192
# 104         2001-05-21                IT    2014 Jabberwocky Rd       26192
# ...                ...               ...                    ...         ...
# 202         2007-08-17         Marketing        147 Spadina Ave     M5V 2L7
# 203         2004-06-07   Human Resources         8204 Arthur St         NaN
# 204         2004-06-07  Public Relations  Schwanthalerstr. 7031       80925
# 205         2004-06-07        Accounting        2004 Charade Rd       98199
# 206         2004-06-07        Accounting        2004 Charade Rd       98199
#
#                   city                   country
# employee_id
# 100            Seattle  United States of America
# 101            Seattle  United States of America
# 102            Seattle  United States of America
# 103          Southlake  United States of America
# 104          Southlake  United States of America
# ...                ...                       ...
# 202            Toronto                    Canada
# 203             London            United Kingdom
# 204             Munich                   Germany
# 205            Seattle  United States of America
# 206            Seattle  United States of America
#
# [107 rows x 10 columns]

# %% [markdown]
# ## Data exploration
#
# What we should explore:
# - what data type we have in each column, are they proper?
# - do we have `null`s or `NaN` values in any column - it's possible that we'll have to deal with them somehow.

# %%
type(emps)
# Out:
# pandas.core.frame.DataFrame

# %%
emps.dtypes
# Out:
# first_name                 object
# last_name                  object
# job_title                  object
# salary                      int64
# hire_date          datetime64[ns]
# department_name            object
# address                    object
# postal_code                object
# city                       object
# country                    object
# dtype: object

# %%
emps.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 107 entries, 100 to 206
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   first_name       107 non-null    object
#  1   last_name        107 non-null    object
#  2   job_title        107 non-null    object
#  3   salary           107 non-null    int64
#  4   hire_date        107 non-null    datetime64[ns]
#  5   department_name  106 non-null    object
#  6   address          106 non-null    object
#  7   postal_code      105 non-null    object
#  8   city             106 non-null    object
#  9   country          106 non-null    object
# dtypes: datetime64[ns](1), int64(1), object(8)
# memory usage: 9.2+ KB

# %%
# 25 percentile means that 25% of salaries are equal or lower than 3 100.
emps.describe()
# Out:
#              salary
# count    107.000000
# mean    6461.682243
# std     3909.365746
# min     2100.000000
# 25%     3100.000000
# 50%     6200.000000
# 75%     8900.000000
# max    24000.000000

# %%
emps.describe(include='all')
# Out:
# /var/folders/__/0gvd5dsj22b9cbv4hzvln3pw0000gn/T/ipykernel_40960/538150911.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   emps.describe(include='all')
#        first_name last_name             job_title        salary  \
# count         107       107                   107    107.000000
# unique         91       102                    19           NaN
# top         Peter      King  Sales Representative           NaN
# freq            3         2                    30           NaN
# first         NaN       NaN                   NaN           NaN
# last          NaN       NaN                   NaN           NaN
# mean          NaN       NaN                   NaN   6461.682243
# std           NaN       NaN                   NaN   3909.365746
# min           NaN       NaN                   NaN   2100.000000
# 25%           NaN       NaN                   NaN   3100.000000
# 50%           NaN       NaN                   NaN   6200.000000
# 75%           NaN       NaN                   NaN   8900.000000
# max           NaN       NaN                   NaN  24000.000000
#
#                   hire_date department_name              address postal_code  \
# count                   107             106                  106         105
# unique                   99              11                    7           6
# top     2004-06-07 00:00:00        Shipping  2011 Interiors Blvd       99236
# freq                      4              45                   45          45
# first   1987-09-17 00:00:00             NaN                  NaN         NaN
# last    2011-02-06 00:00:00             NaN                  NaN         NaN
# mean                    NaN             NaN                  NaN         NaN
# std                     NaN             NaN                  NaN         NaN
# min                     NaN             NaN                  NaN         NaN
# 25%                     NaN             NaN                  NaN         NaN
# 50%                     NaN             NaN                  NaN         NaN
# 75%                     NaN             NaN                  NaN         NaN
# max                     NaN             NaN                  NaN         NaN
#
#                        city                   country
# count                   106                       106
# unique                    7                         4
# top     South San Francisco  United States of America
# freq                     45                        68
# first                   NaN                       NaN
# last                    NaN                       NaN
# mean                    NaN                       NaN
# std                     NaN                       NaN
# min                     NaN                       NaN
# 25%                     NaN                       NaN
# 50%                     NaN                       NaN
# 75%                     NaN                       NaN
# max                     NaN                       NaN

# %%
emps.columns
# Out:
# Index(['first_name', 'last_name', 'job_title', 'salary', 'hire_date',
#        'department_name', 'address', 'postal_code', 'city', 'country'],
#       dtype='object')

# %%
emps.shape  # how many rows (.shape[0]) and columns (.shape[1])
# Out:
# (107, 10)

# %%
len(emps), emps.size
# Out:
# (107, 1070)

# %% [markdown]
# ## Accessing data
#
# ### Columns

# %% [markdown]
# The two options we have to access columns in a DataFrame
# - "dictionary notation" or using indexing operator
# - "object notation"

# %%
emps['last_name']  # "dictionary notation" or using indexing operator
# Out:
# employee_id
# 100       King
# 101    Kochhar
# 102    De Haan
# 103     Hunold
# 104      Ernst
#         ...
# 202        Fay
# 203     Mavris
# 204       Baer
# 205    Higgins
# 206      Gietz
# Name: last_name, Length: 107, dtype: object

# %%
emps.last_name  # "object notation", this will work if the column name does not contain spaces or any other special characters
# Out:
# employee_id
# 100       King
# 101    Kochhar
# 102    De Haan
# 103     Hunold
# 104      Ernst
#         ...
# 202        Fay
# 203     Mavris
# 204       Baer
# 205    Higgins
# 206      Gietz
# Name: last_name, Length: 107, dtype: object

# %% [markdown]
# When access column I'm getting `pandas.core.series.Series` object.

# %%
type(emps.last_name)
# Out:
# pandas.core.series.Series

# %%
emps.salary.mean(), emps.salary.min(), emps.salary.max()
# Out:
# (6461.682242990654, 2100, 24000)

# %% [markdown]
# Quite often we want to take several columns from the DataFrame. To do that we need to provide a list of columns we want to get.

# %%
emps[['first_name', 'last_name', 'salary']]
# Out:
#             first_name last_name  salary
# employee_id
# 100             Steven      King   24000
# 101              Neena   Kochhar   17000
# 102                Lex   De Haan   17000
# 103          Alexander    Hunold    9000
# 104              Bruce     Ernst    6000
# ...                ...       ...     ...
# 202                Pat       Fay    6000
# 203              Susan    Mavris    6500
# 204            Hermann      Baer   10000
# 205            Shelley   Higgins   12000
# 206            William     Gietz    8300
#
# [107 rows x 3 columns]

# %%
emps.job_title
# Out:
# employee_id
# 100                          President
# 101      Administration Vice President
# 102      Administration Vice President
# 103                         Programmer
# 104                         Programmer
#                     ...
# 202           Marketing Representative
# 203     Human Resources Representative
# 204    Public Relations Representative
# 205                 Accounting Manager
# 206                  Public Accountant
# Name: job_title, Length: 107, dtype: object

# %%
emps.job_title.unique()
# Out:
# array(['President', 'Administration Vice President', 'Programmer',
#        'Finance Manager', 'Accountant', 'Purchasing Manager',
#        'Purchasing Clerk', 'Stock Manager', 'Stock Clerk',
#        'Sales Manager', 'Sales Representative', 'Shipping Clerk',
#        'Administration Assistant', 'Marketing Manager',
#        'Marketing Representative', 'Human Resources Representative',
#        'Public Relations Representative', 'Accounting Manager',
#        'Public Accountant'], dtype=object)

# %%
emps.job_title.nunique()
# Out:
# 19

# %% [markdown]
# ### Rows
#
# Data Frame is composed out of Series objects that share the same index.
#
# We have two types of indexes:
# - `loc` - label index, "business index" that we can set during DataFrame creation, we can have numbers, strings as a business index. [Docs](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.loc.html)
# - `iloc` - integer-based indexing, position based on an integer number, starting with 0. [Docs](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.iloc.html)

# %% [markdown]
# #### `iloc`

# %%
emps.iloc[0], type(emps.iloc[0])
# Out:
# (first_name                           Steven
#  last_name                              King
#  job_title                         President
#  salary                                24000
#  hire_date               1997-06-17 00:00:00
#  department_name                   Executive
#  address                     2004 Charade Rd
#  postal_code                           98199
#  city                                Seattle
#  country            United States of America
#  Name: 100, dtype: object,
#  pandas.core.series.Series)

# %%
emps.iloc[0, 1]
# Out:
# 'King'

# %% [markdown]
# We can leverage ranges we know from python and NumPy.

# %%
emps.iloc[10:20:2, 0:3]
# Out:
#               first_name last_name           job_title
# employee_id
# 110                 John      Chen          Accountant
# 112          Jose Manuel     Urman          Accountant
# 114                  Den  Raphaely  Purchasing Manager
# 116               Shelli     Baida    Purchasing Clerk
# 118                  Guy    Himuro    Purchasing Clerk

# %%
emps.iloc[-1]  # negative indexes works exatcly the same
# Out:
# first_name                          William
# last_name                             Gietz
# job_title                 Public Accountant
# salary                                 8300
# hire_date               2004-06-07 00:00:00
# department_name                  Accounting
# address                     2004 Charade Rd
# postal_code                           98199
# city                                Seattle
# country            United States of America
# Name: 206, dtype: object

# %%
emps.iloc[-5:]  # last 5 rows, so wildcard ":" are working exactly the same as when we were using idexing operator for lists
# Out:
#             first_name last_name                        job_title  salary  \
# employee_id
# 202                Pat       Fay         Marketing Representative    6000
# 203              Susan    Mavris   Human Resources Representative    6500
# 204            Hermann      Baer  Public Relations Representative   10000
# 205            Shelley   Higgins               Accounting Manager   12000
# 206            William     Gietz                Public Accountant    8300
#
#              hire_date   department_name                address postal_code  \
# employee_id
# 202         2007-08-17         Marketing        147 Spadina Ave     M5V 2L7
# 203         2004-06-07   Human Resources         8204 Arthur St         NaN
# 204         2004-06-07  Public Relations  Schwanthalerstr. 7031       80925
# 205         2004-06-07        Accounting        2004 Charade Rd       98199
# 206         2004-06-07        Accounting        2004 Charade Rd       98199
#
#                 city                   country
# employee_id
# 202          Toronto                    Canada
# 203           London            United Kingdom
# 204           Munich                   Germany
# 205          Seattle  United States of America
# 206          Seattle  United States of America

# %% [markdown]
# In addition to standar way of working for indexing operator we can provide numbers of rows and/or columns we want to get.

# %%
emps.iloc[-5:, [0, 1, 3]]
# Out:
#             first_name last_name  salary
# employee_id
# 202                Pat       Fay    6000
# 203              Susan    Mavris    6500
# 204            Hermann      Baer   10000
# 205            Shelley   Higgins   12000
# 206            William     Gietz    8300

# %% [markdown]
# #### `loc`
#
# labeled index - for rows we use values from the column we've marked as an index column, for columns we can use column names.

# %%
emps.loc[100, 'last_name']
# Out:
# 'King'

# %%
emps.loc[100]
# Out:
# first_name                           Steven
# last_name                              King
# job_title                         President
# salary                                24000
# hire_date               1997-06-17 00:00:00
# department_name                   Executive
# address                     2004 Charade Rd
# postal_code                           98199
# city                                Seattle
# country            United States of America
# Name: 100, dtype: object

# %%
emps.loc[:, 'last_name']
# Out:
# employee_id
# 100       King
# 101    Kochhar
# 102    De Haan
# 103     Hunold
# 104      Ernst
#         ...
# 202        Fay
# 203     Mavris
# 204       Baer
# 205    Higgins
# 206      Gietz
# Name: last_name, Length: 107, dtype: object

# %%
emps.loc[:, ['first_name', 'last_name']]
# Out:
#             first_name last_name
# employee_id
# 100             Steven      King
# 101              Neena   Kochhar
# 102                Lex   De Haan
# 103          Alexander    Hunold
# 104              Bruce     Ernst
# ...                ...       ...
# 202                Pat       Fay
# 203              Susan    Mavris
# 204            Hermann      Baer
# 205            Shelley   Higgins
# 206            William     Gietz
#
# [107 rows x 2 columns]

# %%
emps.loc[[100, 101], 'last_name']
# Out:
# employee_id
# 100       King
# 101    Kochhar
# Name: last_name, dtype: object

# %%
emps.loc[[100, 101], ['first_name', 'last_name']]
# Out:
#             first_name last_name
# employee_id
# 100             Steven      King
# 101              Neena   Kochhar

# %% [markdown]
# ## Iterating through DataFrame

# %% [markdown]
# The following approach is possible but we shouldn't use, it's not really a best practise and it's not really convenient.

# %%
for column in emps:  # iterating over column names
    for val in emps[column]:
        print(column, val)
# Out:
# first_name Steven
# first_name Neena
# first_name Lex
# first_name Alexander
# first_name Bruce
# first_name David
# first_name Valli
# first_name Diana
# first_name Nancy
# first_name Daniel
# first_name John
# first_name Ismael
# first_name Jose Manuel
# first_name Luis
# first_name Den
# first_name Alexander
# first_name Shelli
# first_name Sigal
# first_name Guy
# first_name Karen
# first_name Matthew
# first_name Adam
# first_name Payam
# first_name Shanta
# first_name Kevin
# first_name Julia
# first_name Irene
# first_name James
# first_name Steven
# first_name Laura
# first_name Mozhe
# first_name James
# first_name TJ
# first_name Jason
# first_name Michael
# first_name Ki
# first_name Hazel
# first_name Renske
# first_name Stephen
# first_name John
# first_name Joshua
# first_name Trenna
# first_name Curtis
# first_name Randall
# first_name Peter
# first_name John
# first_name Karen
# first_name Alberto
# first_name Gerald
# first_name Eleni
# first_name Peter
# first_name David
# first_name Peter
# first_name Christopher
# first_name Nanette
# first_name Oliver
# first_name Janette
# first_name Patrick
# first_name Allan
# first_name Lindsey
# first_name Louise
# first_name Sarath
# first_name Clara
# first_name Danielle
# first_name Mattea
# first_name David
# first_name Sundar
# first_name Amit
# first_name Lisa
# first_name Harrison
# first_name Tayler
# first_name William
# first_name Elizabeth
# first_name Sundita
# first_name Ellen
# first_name Alyssa
# first_name Jonathon
# first_name Jack
# first_name Kimberely
# first_name Charles
# first_name Winston
# first_name Jean
# first_name Martha
# first_name Girard
# first_name Nandita
# first_name Alexis
# first_name Julia
# first_name Anthony
# first_name Kelly
# first_name Jennifer
# first_name Timothy
# first_name Randall
# first_name Sarah
# first_name Britney
# first_name Samuel
# first_name Vance
# first_name Alana
# first_name Kevin
# first_name Donald
# first_name Douglas
# first_name Jennifer
# first_name Michael
# first_name Pat
# first_name Susan
# first_name Hermann
# first_name Shelley
# first_name William
# last_name King
# last_name Kochhar
# last_name De Haan
# last_name Hunold
# last_name Ernst
# last_name Austin
# last_name Pataballa
# last_name Lorentz
# last_name Greenberg
# last_name Faviet
# last_name Chen
# last_name Sciarra
# last_name Urman
# last_name Popp
# last_name Raphaely
# last_name Khoo
# last_name Baida
# last_name Tobias
# last_name Himuro
# last_name Colmenares
# last_name Weiss
# last_name Fripp
# last_name Kaufling
# last_name Vollman
# last_name Mourgos
# last_name Nayer
# last_name Mikkilineni
# last_name Landry
# last_name Markle
# last_name Bissot
# last_name Atkinson
# last_name Marlow
# last_name Olson
# last_name Mallin
# last_name Rogers
# last_name Gee
# last_name Philtanker
# last_name Ladwig
# last_name Stiles
# last_name Seo
# last_name Patel
# last_name Rajs
# last_name Davies
# last_name Matos
# last_name Vargas
# last_name Russell
# last_name Partners
# last_name Errazuriz
# last_name Cambrault
# last_name Zlotkey
# last_name Tucker
# last_name Bernstein
# last_name Hall
# last_name Olsen
# last_name Cambrault
# last_name Tuvault
# last_name King
# last_name Sully
# last_name McEwen
# last_name Smith
# last_name Doran
# last_name Sewall
# last_name Vishney
# last_name Greene
# last_name Marvins
# last_name Lee
# last_name Ande
# last_name Banda
# last_name Ozer
# last_name Bloom
# last_name Fox
# last_name Smith
# last_name Bates
# last_name Kumar
# last_name Abel
# last_name Hutton
# last_name Taylor
# last_name Livingston
# last_name Grant
# last_name Johnson
# last_name Taylor
# last_name Fleaur
# last_name Sullivan
# last_name Geoni
# last_name Sarchand
# last_name Bull
# last_name Dellinger
# last_name Cabrio
# last_name Chung
# last_name Dilly
# last_name Gates
# last_name Perkins
# last_name Bell
# last_name Everett
# last_name McCain
# last_name Jones
# last_name Walsh
# last_name Feeney
# last_name OConnell
# last_name Grant
# last_name Whalen
# last_name Hartstein
# last_name Fay
# last_name Mavris
# last_name Baer
# last_name Higgins
# last_name Gietz
# job_title President
# job_title Administration Vice President
# job_title Administration Vice President
# job_title Programmer
# job_title Programmer
# job_title Programmer
# job_title Programmer
# job_title Programmer
# job_title Finance Manager
# job_title Accountant
# job_title Accountant
# job_title Accountant
# job_title Accountant
# job_title Accountant
# job_title Purchasing Manager
# job_title Purchasing Clerk
# job_title Purchasing Clerk
# job_title Purchasing Clerk
# job_title Purchasing Clerk
# job_title Purchasing Clerk
# job_title Stock Manager
# job_title Stock Manager
# job_title Stock Manager
# job_title Stock Manager
# job_title Stock Manager
# job_title Stock Clerk
# job_title Stock Clerk
# job_title Stock Clerk
# job_title Stock Clerk
# job_title Stock Clerk
# job_title Stock Clerk
# job_title Stock Clerk
# job_title Stock Clerk
# job_title Stock Clerk
# job_title Stock Clerk
# job_title Stock Clerk
# job_title Stock Clerk
# job_title Stock Clerk
# job_title Stock Clerk
# job_title Stock Clerk
# job_title Stock Clerk
# job_title Stock Clerk
# job_title Stock Clerk
# job_title Stock Clerk
# job_title Stock Clerk
# job_title Sales Manager
# job_title Sales Manager
# job_title Sales Manager
# job_title Sales Manager
# job_title Sales Manager
# job_title Sales Representative
# job_title Sales Representative
# job_title Sales Representative
# job_title Sales Representative
# job_title Sales Representative
# job_title Sales Representative
# job_title Sales Representative
# job_title Sales Representative
# job_title Sales Representative
# job_title Sales Representative
# job_title Sales Representative
# job_title Sales Representative
# job_title Sales Representative
# job_title Sales Representative
# job_title Sales Representative
# job_title Sales Representative
# job_title Sales Representative
# job_title Sales Representative
# job_title Sales Representative
# job_title Sales Representative
# job_title Sales Representative
# job_title Sales Representative
# job_title Sales Representative
# job_title Sales Representative
# job_title Sales Representative
# job_title Sales Representative
# job_title Sales Representative
# job_title Sales Representative
# job_title Sales Representative
# job_title Sales Representative
# job_title Shipping Clerk
# job_title Shipping Clerk
# job_title Shipping Clerk
# job_title Shipping Clerk
# job_title Shipping Clerk
# job_title Shipping Clerk
# job_title Shipping Clerk
# job_title Shipping Clerk
# job_title Shipping Clerk
# job_title Shipping Clerk
# job_title Shipping Clerk
# job_title Shipping Clerk
# job_title Shipping Clerk
# job_title Shipping Clerk
# job_title Shipping Clerk
# job_title Shipping Clerk
# job_title Shipping Clerk
# job_title Shipping Clerk
# job_title Shipping Clerk
# job_title Shipping Clerk
# job_title Administration Assistant
# job_title Marketing Manager
# job_title Marketing Representative
# job_title Human Resources Representative
# job_title Public Relations Representative
# job_title Accounting Manager
# job_title Public Accountant
# salary 24000
# salary 17000
# salary 17000
# salary 9000
# salary 6000
# salary 4800
# salary 4800
# salary 4200
# salary 12000
# salary 9000
# salary 8200
# salary 7700
# salary 7800
# salary 6900
# salary 11000
# salary 3100
# salary 2900
# salary 2800
# salary 2600
# salary 2500
# salary 8000
# salary 8200
# salary 7900
# salary 6500
# salary 5800
# salary 3200
# salary 2700
# salary 2400
# salary 2200
# salary 3300
# salary 2800
# salary 2500
# salary 2100
# salary 3300
# salary 2900
# salary 2400
# salary 2200
# salary 3600
# salary 3200
# salary 2700
# salary 2500
# salary 3500
# salary 3100
# salary 2600
# salary 2500
# salary 14000
# salary 13500
# salary 12000
# salary 11000
# salary 10500
# salary 10000
# salary 9500
# salary 9000
# salary 8000
# salary 7500
# salary 7000
# salary 10000
# salary 9500
# salary 9000
# salary 8000
# salary 7500
# salary 7000
# salary 10500
# salary 9500
# salary 7200
# salary 6800
# salary 6400
# salary 6200
# salary 11500
# salary 10000
# salary 9600
# salary 7400
# salary 7300
# salary 6100
# salary 11000
# salary 8800
# salary 8600
# salary 8400
# salary 7000
# salary 6200
# salary 3200
# salary 3100
# salary 2500
# salary 2800
# salary 4200
# salary 4100
# salary 3400
# salary 3000
# salary 3800
# salary 3600
# salary 2900
# salary 2500
# salary 4000
# salary 3900
# salary 3200
# salary 2800
# salary 3100
# salary 3000
# salary 2600
# salary 2600
# salary 4400
# salary 13000
# salary 6000
# salary 6500
# salary 10000
# salary 12000
# salary 8300
# hire_date 1997-06-17 00:00:00
# hire_date 1999-09-21 00:00:00
# hire_date 2003-01-13 00:00:00
# hire_date 2000-01-03 00:00:00
# hire_date 2001-05-21 00:00:00
# hire_date 2007-06-25 00:00:00
# hire_date 2008-02-05 00:00:00
# hire_date 2009-02-07 00:00:00
# hire_date 2004-08-17 00:00:00
# hire_date 2004-08-16 00:00:00
# hire_date 2007-09-28 00:00:00
# hire_date 2007-09-30 00:00:00
# hire_date 1998-03-07 00:00:00
# hire_date 2009-12-07 00:00:00
# hire_date 2004-12-07 00:00:00
# hire_date 2005-05-18 00:00:00
# hire_date 2007-12-24 00:00:00
# hire_date 2007-07-24 00:00:00
# hire_date 2008-11-15 00:00:00
# hire_date 2009-08-10 00:00:00
# hire_date 2006-07-18 00:00:00
# hire_date 2007-04-10 00:00:00
# hire_date 2005-05-01 00:00:00
# hire_date 2007-10-10 00:00:00
# hire_date 2009-11-16 00:00:00
# hire_date 2007-07-16 00:00:00
# hire_date 2008-09-28 00:00:00
# hire_date 2009-01-14 00:00:00
# hire_date 2010-03-08 00:00:00
# hire_date 2007-08-20 00:00:00
# hire_date 2007-10-30 00:00:00
# hire_date 2007-02-16 00:00:00
# hire_date 2009-04-10 00:00:00
# hire_date 2006-06-14 00:00:00
# hire_date 2008-08-26 00:00:00
# hire_date 2009-12-12 00:00:00
# hire_date 2011-02-06 00:00:00
# hire_date 2005-07-14 00:00:00
# hire_date 2007-10-26 00:00:00
# hire_date 2008-02-12 00:00:00
# hire_date 2008-04-06 00:00:00
# hire_date 2005-10-17 00:00:00
# hire_date 2007-01-29 00:00:00
# hire_date 2008-03-15 00:00:00
# hire_date 2008-07-09 00:00:00
# hire_date 2006-10-01 00:00:00
# hire_date 2007-01-05 00:00:00
# hire_date 2007-03-10 00:00:00
# hire_date 2009-10-15 00:00:00
# hire_date 2000-01-29 00:00:00
# hire_date 2007-01-30 00:00:00
# hire_date 2007-03-24 00:00:00
# hire_date 2007-08-20 00:00:00
# hire_date 2008-03-30 00:00:00
# hire_date 2008-12-09 00:00:00
# hire_date 2009-11-23 00:00:00
# hire_date 2006-01-30 00:00:00
# hire_date 2006-03-04 00:00:00
# hire_date 2006-08-01 00:00:00
# hire_date 2007-03-10 00:00:00
# hire_date 2007-12-15 00:00:00
# hire_date 2008-11-03 00:00:00
# hire_date 2007-11-11 00:00:00
# hire_date 2009-03-19 00:00:00
# hire_date 2010-01-24 00:00:00
# hire_date 2000-02-23 00:00:00
# hire_date 2000-03-24 00:00:00
# hire_date 2000-04-21 00:00:00
# hire_date 2007-03-11 00:00:00
# hire_date 2008-03-23 00:00:00
# hire_date 2008-01-24 00:00:00
# hire_date 2009-02-23 00:00:00
# hire_date 2009-03-24 00:00:00
# hire_date 2010-04-21 00:00:00
# hire_date 2006-05-11 00:00:00
# hire_date 2007-03-19 00:00:00
# hire_date 2008-03-24 00:00:00
# hire_date 2008-04-23 00:00:00
# hire_date 2009-05-24 00:00:00
# hire_date 2011-01-04 00:00:00
# hire_date 2008-01-24 00:00:00
# hire_date 2008-02-23 00:00:00
# hire_date 2009-06-21 00:00:00
# hire_date 2000-02-03 00:00:00
# hire_date 2006-01-27 00:00:00
# hire_date 2007-02-20 00:00:00
# hire_date 2008-06-24 00:00:00
# hire_date 2009-02-07 00:00:00
# hire_date 2007-06-14 00:00:00
# hire_date 2007-08-13 00:00:00
# hire_date 2008-07-11 00:00:00
# hire_date 2009-12-19 00:00:00
# hire_date 2006-02-04 00:00:00
# hire_date 2007-03-03 00:00:00
# hire_date 2008-07-01 00:00:00
# hire_date 2009-03-17 00:00:00
# hire_date 2008-04-24 00:00:00
# hire_date 2008-05-23 00:00:00
# hire_date 2009-06-21 00:00:00
# hire_date 2010-01-13 00:00:00
# hire_date 1987-09-17 00:00:00
# hire_date 2006-02-17 00:00:00
# hire_date 2007-08-17 00:00:00
# hire_date 2004-06-07 00:00:00
# hire_date 2004-06-07 00:00:00
# hire_date 2004-06-07 00:00:00
# hire_date 2004-06-07 00:00:00
# department_name Executive
# department_name Executive
# department_name Executive
# department_name IT
# department_name IT
# department_name IT
# department_name IT
# department_name IT
# department_name Finance
# department_name Finance
# department_name Finance
# department_name Finance
# department_name Finance
# department_name Finance
# department_name Purchasing
# department_name Purchasing
# department_name Purchasing
# department_name Purchasing
# department_name Purchasing
# department_name Purchasing
# department_name Shipping
# department_name Shipping
# department_name Shipping
# department_name Shipping
# department_name Shipping
# department_name Shipping
# department_name Shipping
# department_name Shipping
# department_name Shipping
# department_name Shipping
# department_name Shipping
# department_name Shipping
# department_name Shipping
# department_name Shipping
# department_name Shipping
# department_name Shipping
# department_name Shipping
# department_name Shipping
# department_name Shipping
# department_name Shipping
# department_name Shipping
# department_name Shipping
# department_name Shipping
# department_name Shipping
# department_name Shipping
# department_name Sales
# department_name Sales
# department_name Sales
# department_name Sales
# department_name Sales
# department_name Sales
# department_name Sales
# department_name Sales
# department_name Sales
# department_name Sales
# department_name Sales
# department_name Sales
# department_name Sales
# department_name Sales
# department_name Sales
# department_name Sales
# department_name Sales
# department_name Sales
# department_name Sales
# department_name Sales
# department_name Sales
# department_name Sales
# department_name Sales
# department_name Sales
# department_name Sales
# department_name Sales
# department_name Sales
# department_name Sales
# department_name Sales
# department_name Sales
# department_name Sales
# department_name Sales
# department_name Sales
# department_name nan
# department_name Sales
# department_name Shipping
# department_name Shipping
# department_name Shipping
# department_name Shipping
# department_name Shipping
# department_name Shipping
# department_name Shipping
# department_name Shipping
# department_name Shipping
# department_name Shipping
# department_name Shipping
# department_name Shipping
# department_name Shipping
# department_name Shipping
# department_name Shipping
# department_name Shipping
# department_name Shipping
# department_name Shipping
# department_name Shipping
# department_name Shipping
# department_name Administration
# department_name Marketing
# department_name Marketing
# department_name Human Resources
# department_name Public Relations
# department_name Accounting
# department_name Accounting
# address 2004 Charade Rd
# address 2004 Charade Rd
# address 2004 Charade Rd
# address 2014 Jabberwocky Rd
# address 2014 Jabberwocky Rd
# address 2014 Jabberwocky Rd
# address 2014 Jabberwocky Rd
# address 2014 Jabberwocky Rd
# address 2004 Charade Rd
# address 2004 Charade Rd
# address 2004 Charade Rd
# address 2004 Charade Rd
# address 2004 Charade Rd
# address 2004 Charade Rd
# address 2004 Charade Rd
# address 2004 Charade Rd
# address 2004 Charade Rd
# address 2004 Charade Rd
# address 2004 Charade Rd
# address 2004 Charade Rd
# address 2011 Interiors Blvd
# address 2011 Interiors Blvd
# address 2011 Interiors Blvd
# address 2011 Interiors Blvd
# address 2011 Interiors Blvd
# address 2011 Interiors Blvd
# address 2011 Interiors Blvd
# address 2011 Interiors Blvd
# address 2011 Interiors Blvd
# address 2011 Interiors Blvd
# address 2011 Interiors Blvd
# address 2011 Interiors Blvd
# address 2011 Interiors Blvd
# address 2011 Interiors Blvd
# address 2011 Interiors Blvd
# address 2011 Interiors Blvd
# address 2011 Interiors Blvd
# address 2011 Interiors Blvd
# address 2011 Interiors Blvd
# address 2011 Interiors Blvd
# address 2011 Interiors Blvd
# address 2011 Interiors Blvd
# address 2011 Interiors Blvd
# address 2011 Interiors Blvd
# address 2011 Interiors Blvd
# address Magdalen Centre, The Oxford Science Park
# address Magdalen Centre, The Oxford Science Park
# address Magdalen Centre, The Oxford Science Park
# address Magdalen Centre, The Oxford Science Park
# address Magdalen Centre, The Oxford Science Park
# address Magdalen Centre, The Oxford Science Park
# address Magdalen Centre, The Oxford Science Park
# address Magdalen Centre, The Oxford Science Park
# address Magdalen Centre, The Oxford Science Park
# address Magdalen Centre, The Oxford Science Park
# address Magdalen Centre, The Oxford Science Park
# address Magdalen Centre, The Oxford Science Park
# address Magdalen Centre, The Oxford Science Park
# address Magdalen Centre, The Oxford Science Park
# address Magdalen Centre, The Oxford Science Park
# address Magdalen Centre, The Oxford Science Park
# address Magdalen Centre, The Oxford Science Park
# address Magdalen Centre, The Oxford Science Park
# address Magdalen Centre, The Oxford Science Park
# address Magdalen Centre, The Oxford Science Park
# address Magdalen Centre, The Oxford Science Park
# address Magdalen Centre, The Oxford Science Park
# address Magdalen Centre, The Oxford Science Park
# address Magdalen Centre, The Oxford Science Park
# address Magdalen Centre, The Oxford Science Park
# address Magdalen Centre, The Oxford Science Park
# address Magdalen Centre, The Oxford Science Park
# address Magdalen Centre, The Oxford Science Park
# address Magdalen Centre, The Oxford Science Park
# address Magdalen Centre, The Oxford Science Park
# address Magdalen Centre, The Oxford Science Park
# address Magdalen Centre, The Oxford Science Park
# address Magdalen Centre, The Oxford Science Park
# address nan
# address Magdalen Centre, The Oxford Science Park
# address 2011 Interiors Blvd
# address 2011 Interiors Blvd
# address 2011 Interiors Blvd
# address 2011 Interiors Blvd
# address 2011 Interiors Blvd
# address 2011 Interiors Blvd
# address 2011 Interiors Blvd
# address 2011 Interiors Blvd
# address 2011 Interiors Blvd
# address 2011 Interiors Blvd
# address 2011 Interiors Blvd
# address 2011 Interiors Blvd
# address 2011 Interiors Blvd
# address 2011 Interiors Blvd
# address 2011 Interiors Blvd
# address 2011 Interiors Blvd
# address 2011 Interiors Blvd
# address 2011 Interiors Blvd
# address 2011 Interiors Blvd
# address 2011 Interiors Blvd
# address 2004 Charade Rd
# address 147 Spadina Ave
# address 147 Spadina Ave
# address 8204 Arthur St
# address Schwanthalerstr. 7031
# address 2004 Charade Rd
# address 2004 Charade Rd
# postal_code 98199
# postal_code 98199
# postal_code 98199
# postal_code 26192
# postal_code 26192
# postal_code 26192
# postal_code 26192
# postal_code 26192
# postal_code 98199
# postal_code 98199
# postal_code 98199
# postal_code 98199
# postal_code 98199
# postal_code 98199
# postal_code 98199
# postal_code 98199
# postal_code 98199
# postal_code 98199
# postal_code 98199
# postal_code 98199
# postal_code 99236
# postal_code 99236
# postal_code 99236
# postal_code 99236
# postal_code 99236
# postal_code 99236
# postal_code 99236
# postal_code 99236
# postal_code 99236
# postal_code 99236
# postal_code 99236
# postal_code 99236
# postal_code 99236
# postal_code 99236
# postal_code 99236
# postal_code 99236
# postal_code 99236
# postal_code 99236
# postal_code 99236
# postal_code 99236
# postal_code 99236
# postal_code 99236
# postal_code 99236
# postal_code 99236
# postal_code 99236
# postal_code OX9 9ZB
# postal_code OX9 9ZB
# postal_code OX9 9ZB
# postal_code OX9 9ZB
# postal_code OX9 9ZB
# postal_code OX9 9ZB
# postal_code OX9 9ZB
# postal_code OX9 9ZB
# postal_code OX9 9ZB
# postal_code OX9 9ZB
# postal_code OX9 9ZB
# postal_code OX9 9ZB
# postal_code OX9 9ZB
# postal_code OX9 9ZB
# postal_code OX9 9ZB
# postal_code OX9 9ZB
# postal_code OX9 9ZB
# postal_code OX9 9ZB
# postal_code OX9 9ZB
# postal_code OX9 9ZB
# postal_code OX9 9ZB
# postal_code OX9 9ZB
# postal_code OX9 9ZB
# postal_code OX9 9ZB
# postal_code OX9 9ZB
# postal_code OX9 9ZB
# postal_code OX9 9ZB
# postal_code OX9 9ZB
# postal_code OX9 9ZB
# postal_code OX9 9ZB
# postal_code OX9 9ZB
# postal_code OX9 9ZB
# postal_code OX9 9ZB
# postal_code nan
# postal_code OX9 9ZB
# postal_code 99236
# postal_code 99236
# postal_code 99236
# postal_code 99236
# postal_code 99236
# postal_code 99236
# postal_code 99236
# postal_code 99236
# postal_code 99236
# postal_code 99236
# postal_code 99236
# postal_code 99236
# postal_code 99236
# postal_code 99236
# postal_code 99236
# postal_code 99236
# postal_code 99236
# postal_code 99236
# postal_code 99236
# postal_code 99236
# postal_code 98199
# postal_code M5V 2L7
# postal_code M5V 2L7
# postal_code nan
# postal_code 80925
# postal_code 98199
# postal_code 98199
# city Seattle
# city Seattle
# city Seattle
# city Southlake
# city Southlake
# city Southlake
# city Southlake
# city Southlake
# city Seattle
# city Seattle
# city Seattle
# city Seattle
# city Seattle
# city Seattle
# city Seattle
# city Seattle
# city Seattle
# city Seattle
# city Seattle
# city Seattle
# city South San Francisco
# city South San Francisco
# city South San Francisco
# city South San Francisco
# city South San Francisco
# city South San Francisco
# city South San Francisco
# city South San Francisco
# city South San Francisco
# city South San Francisco
# city South San Francisco
# city South San Francisco
# city South San Francisco
# city South San Francisco
# city South San Francisco
# city South San Francisco
# city South San Francisco
# city South San Francisco
# city South San Francisco
# city South San Francisco
# city South San Francisco
# city South San Francisco
# city South San Francisco
# city South San Francisco
# city South San Francisco
# city Oxford
# city Oxford
# city Oxford
# city Oxford
# city Oxford
# city Oxford
# city Oxford
# city Oxford
# city Oxford
# city Oxford
# city Oxford
# city Oxford
# city Oxford
# city Oxford
# city Oxford
# city Oxford
# city Oxford
# city Oxford
# city Oxford
# city Oxford
# city Oxford
# city Oxford
# city Oxford
# city Oxford
# city Oxford
# city Oxford
# city Oxford
# city Oxford
# city Oxford
# city Oxford
# city Oxford
# city Oxford
# city Oxford
# city nan
# city Oxford
# city South San Francisco
# city South San Francisco
# city South San Francisco
# city South San Francisco
# city South San Francisco
# city South San Francisco
# city South San Francisco
# city South San Francisco
# city South San Francisco
# city South San Francisco
# city South San Francisco
# city South San Francisco
# city South San Francisco
# city South San Francisco
# city South San Francisco
# city South San Francisco
# city South San Francisco
# city South San Francisco
# city South San Francisco
# city South San Francisco
# city Seattle
# city Toronto
# city Toronto
# city London
# city Munich
# city Seattle
# city Seattle
# country United States of America
# country United States of America
# country United States of America
# country United States of America
# country United States of America
# country United States of America
# country United States of America
# country United States of America
# country United States of America
# country United States of America
# country United States of America
# country United States of America
# country United States of America
# country United States of America
# country United States of America
# country United States of America
# country United States of America
# country United States of America
# country United States of America
# country United States of America
# country United States of America
# country United States of America
# country United States of America
# country United States of America
# country United States of America
# country United States of America
# country United States of America
# country United States of America
# country United States of America
# country United States of America
# country United States of America
# country United States of America
# country United States of America
# country United States of America
# country United States of America
# country United States of America
# country United States of America
# country United States of America
# country United States of America
# country United States of America
# country United States of America
# country United States of America
# country United States of America
# country United States of America
# country United States of America
# country United Kingdom
# country United Kingdom
# country United Kingdom
# country United Kingdom
# country United Kingdom
# country United Kingdom
# country United Kingdom
# country United Kingdom
# country United Kingdom
# country United Kingdom
# country United Kingdom
# country United Kingdom
# country United Kingdom
# country United Kingdom
# country United Kingdom
# country United Kingdom
# country United Kingdom
# country United Kingdom
# country United Kingdom
# country United Kingdom
# country United Kingdom
# country United Kingdom
# country United Kingdom
# country United Kingdom
# country United Kingdom
# country United Kingdom
# country United Kingdom
# country United Kingdom
# country United Kingdom
# country United Kingdom
# country United Kingdom
# country United Kingdom
# country United Kingdom
# country nan
# country United Kingdom
# country United States of America
# country United States of America
# country United States of America
# country United States of America
# country United States of America
# country United States of America
# country United States of America
# country United States of America
# country United States of America
# country United States of America
# country United States of America
# country United States of America
# country United States of America
# country United States of America
# country United States of America
# country United States of America
# country United States of America
# country United States of America
# country United States of America
# country United States of America
# country United States of America
# country Canada
# country Canada
# country United Kingdom
# country Germany
# country United States of America
# country United States of America

# %% [markdown]
# Much better (and convenient) approach is to use [`.iterrows()`](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.iterrows.html) method.

# %%
for row_index, row_data in emps.iterrows():
    print(row_index, row_data['first_name'], row_data['last_name'], row_data['salary'])
# Out:
# 100 Steven King 24000
# 101 Neena Kochhar 17000
# 102 Lex De Haan 17000
# 103 Alexander Hunold 9000
# 104 Bruce Ernst 6000
# 105 David Austin 4800
# 106 Valli Pataballa 4800
# 107 Diana Lorentz 4200
# 108 Nancy Greenberg 12000
# 109 Daniel Faviet 9000
# 110 John Chen 8200
# 111 Ismael Sciarra 7700
# 112 Jose Manuel Urman 7800
# 113 Luis Popp 6900
# 114 Den Raphaely 11000
# 115 Alexander Khoo 3100
# 116 Shelli Baida 2900
# 117 Sigal Tobias 2800
# 118 Guy Himuro 2600
# 119 Karen Colmenares 2500
# 120 Matthew Weiss 8000
# 121 Adam Fripp 8200
# 122 Payam Kaufling 7900
# 123 Shanta Vollman 6500
# 124 Kevin Mourgos 5800
# 125 Julia Nayer 3200
# 126 Irene Mikkilineni 2700
# 127 James Landry 2400
# 128 Steven Markle 2200
# 129 Laura Bissot 3300
# 130 Mozhe Atkinson 2800
# 131 James Marlow 2500
# 132 TJ Olson 2100
# 133 Jason Mallin 3300
# 134 Michael Rogers 2900
# 135 Ki Gee 2400
# 136 Hazel Philtanker 2200
# 137 Renske Ladwig 3600
# 138 Stephen Stiles 3200
# 139 John Seo 2700
# 140 Joshua Patel 2500
# 141 Trenna Rajs 3500
# 142 Curtis Davies 3100
# 143 Randall Matos 2600
# 144 Peter Vargas 2500
# 145 John Russell 14000
# 146 Karen Partners 13500
# 147 Alberto Errazuriz 12000
# 148 Gerald Cambrault 11000
# 149 Eleni Zlotkey 10500
# 150 Peter Tucker 10000
# 151 David Bernstein 9500
# 152 Peter Hall 9000
# 153 Christopher Olsen 8000
# 154 Nanette Cambrault 7500
# 155 Oliver Tuvault 7000
# 156 Janette King 10000
# 157 Patrick Sully 9500
# 158 Allan McEwen 9000
# 159 Lindsey Smith 8000
# 160 Louise Doran 7500
# 161 Sarath Sewall 7000
# 162 Clara Vishney 10500
# 163 Danielle Greene 9500
# 164 Mattea Marvins 7200
# 165 David Lee 6800
# 166 Sundar Ande 6400
# 167 Amit Banda 6200
# 168 Lisa Ozer 11500
# 169 Harrison Bloom 10000
# 170 Tayler Fox 9600
# 171 William Smith 7400
# 172 Elizabeth Bates 7300
# 173 Sundita Kumar 6100
# 174 Ellen Abel 11000
# 175 Alyssa Hutton 8800
# 176 Jonathon Taylor 8600
# 177 Jack Livingston 8400
# 178 Kimberely Grant 7000
# 179 Charles Johnson 6200
# 180 Winston Taylor 3200
# 181 Jean Fleaur 3100
# 182 Martha Sullivan 2500
# 183 Girard Geoni 2800
# 184 Nandita Sarchand 4200
# 185 Alexis Bull 4100
# 186 Julia Dellinger 3400
# 187 Anthony Cabrio 3000
# 188 Kelly Chung 3800
# 189 Jennifer Dilly 3600
# 190 Timothy Gates 2900
# 191 Randall Perkins 2500
# 192 Sarah Bell 4000
# 193 Britney Everett 3900
# 194 Samuel McCain 3200
# 195 Vance Jones 2800
# 196 Alana Walsh 3100
# 197 Kevin Feeney 3000
# 198 Donald OConnell 2600
# 199 Douglas Grant 2600
# 200 Jennifer Whalen 4400
# 201 Michael Hartstein 13000
# 202 Pat Fay 6000
# 203 Susan Mavris 6500
# 204 Hermann Baer 10000
# 205 Shelley Higgins 12000
# 206 William Gietz 8300

# %% [markdown]
# ## Filtering

# %%
emps.salary > 10_000  # this expression, as with NumPy, returns a mask which we can apply to a DataFrame
# Out:
# employee_id
# 100     True
# 101     True
# 102     True
# 103    False
# 104    False
#        ...
# 202    False
# 203    False
# 204    False
# 205     True
# 206    False
# Name: salary, Length: 107, dtype: bool

# %%
emps[emps.salary > 10_000]
# Out:
#             first_name  last_name                      job_title  salary  \
# employee_id
# 100             Steven       King                      President   24000
# 101              Neena    Kochhar  Administration Vice President   17000
# 102                Lex    De Haan  Administration Vice President   17000
# 108              Nancy  Greenberg                Finance Manager   12000
# 114                Den   Raphaely             Purchasing Manager   11000
# 145               John    Russell                  Sales Manager   14000
# 146              Karen   Partners                  Sales Manager   13500
# 147            Alberto  Errazuriz                  Sales Manager   12000
# 148             Gerald  Cambrault                  Sales Manager   11000
# 149              Eleni    Zlotkey                  Sales Manager   10500
# 162              Clara    Vishney           Sales Representative   10500
# 168               Lisa       Ozer           Sales Representative   11500
# 174              Ellen       Abel           Sales Representative   11000
# 201            Michael  Hartstein              Marketing Manager   13000
# 205            Shelley    Higgins             Accounting Manager   12000
#
#              hire_date department_name  \
# employee_id
# 100         1997-06-17       Executive
# 101         1999-09-21       Executive
# 102         2003-01-13       Executive
# 108         2004-08-17         Finance
# 114         2004-12-07      Purchasing
# 145         2006-10-01           Sales
# 146         2007-01-05           Sales
# 147         2007-03-10           Sales
# 148         2009-10-15           Sales
# 149         2000-01-29           Sales
# 162         2007-11-11           Sales
# 168         2007-03-11           Sales
# 174         2006-05-11           Sales
# 201         2006-02-17       Marketing
# 205         2004-06-07      Accounting
#
#                                               address postal_code     city  \
# employee_id
# 100                                   2004 Charade Rd       98199  Seattle
# 101                                   2004 Charade Rd       98199  Seattle
# 102                                   2004 Charade Rd       98199  Seattle
# 108                                   2004 Charade Rd       98199  Seattle
# 114                                   2004 Charade Rd       98199  Seattle
# 145          Magdalen Centre, The Oxford Science Park     OX9 9ZB   Oxford
# 146          Magdalen Centre, The Oxford Science Park     OX9 9ZB   Oxford
# 147          Magdalen Centre, The Oxford Science Park     OX9 9ZB   Oxford
# 148          Magdalen Centre, The Oxford Science Park     OX9 9ZB   Oxford
# 149          Magdalen Centre, The Oxford Science Park     OX9 9ZB   Oxford
# 162          Magdalen Centre, The Oxford Science Park     OX9 9ZB   Oxford
# 168          Magdalen Centre, The Oxford Science Park     OX9 9ZB   Oxford
# 174          Magdalen Centre, The Oxford Science Park     OX9 9ZB   Oxford
# 201                                   147 Spadina Ave     M5V 2L7  Toronto
# 205                                   2004 Charade Rd       98199  Seattle
#
#                               country
# employee_id
# 100          United States of America
# 101          United States of America
# 102          United States of America
# 108          United States of America
# 114          United States of America
# 145                    United Kingdom
# 146                    United Kingdom
# 147                    United Kingdom
# 148                    United Kingdom
# 149                    United Kingdom
# 162                    United Kingdom
# 168                    United Kingdom
# 174                    United Kingdom
# 201                            Canada
# 205          United States of America

# %%
emps[emps.city == 'Seattle']
# Out:
#               first_name   last_name                      job_title  salary  \
# employee_id
# 100               Steven        King                      President   24000
# 101                Neena     Kochhar  Administration Vice President   17000
# 102                  Lex     De Haan  Administration Vice President   17000
# 108                Nancy   Greenberg                Finance Manager   12000
# 109               Daniel      Faviet                     Accountant    9000
# 110                 John        Chen                     Accountant    8200
# 111               Ismael     Sciarra                     Accountant    7700
# 112          Jose Manuel       Urman                     Accountant    7800
# 113                 Luis        Popp                     Accountant    6900
# 114                  Den    Raphaely             Purchasing Manager   11000
# 115            Alexander        Khoo               Purchasing Clerk    3100
# 116               Shelli       Baida               Purchasing Clerk    2900
# 117                Sigal      Tobias               Purchasing Clerk    2800
# 118                  Guy      Himuro               Purchasing Clerk    2600
# 119                Karen  Colmenares               Purchasing Clerk    2500
# 200             Jennifer      Whalen       Administration Assistant    4400
# 205              Shelley     Higgins             Accounting Manager   12000
# 206              William       Gietz              Public Accountant    8300
#
#              hire_date department_name          address postal_code     city  \
# employee_id
# 100         1997-06-17       Executive  2004 Charade Rd       98199  Seattle
# 101         1999-09-21       Executive  2004 Charade Rd       98199  Seattle
# 102         2003-01-13       Executive  2004 Charade Rd       98199  Seattle
# 108         2004-08-17         Finance  2004 Charade Rd       98199  Seattle
# 109         2004-08-16         Finance  2004 Charade Rd       98199  Seattle
# 110         2007-09-28         Finance  2004 Charade Rd       98199  Seattle
# 111         2007-09-30         Finance  2004 Charade Rd       98199  Seattle
# 112         1998-03-07         Finance  2004 Charade Rd       98199  Seattle
# 113         2009-12-07         Finance  2004 Charade Rd       98199  Seattle
# 114         2004-12-07      Purchasing  2004 Charade Rd       98199  Seattle
# 115         2005-05-18      Purchasing  2004 Charade Rd       98199  Seattle
# 116         2007-12-24      Purchasing  2004 Charade Rd       98199  Seattle
# 117         2007-07-24      Purchasing  2004 Charade Rd       98199  Seattle
# 118         2008-11-15      Purchasing  2004 Charade Rd       98199  Seattle
# 119         2009-08-10      Purchasing  2004 Charade Rd       98199  Seattle
# 200         1987-09-17  Administration  2004 Charade Rd       98199  Seattle
# 205         2004-06-07      Accounting  2004 Charade Rd       98199  Seattle
# 206         2004-06-07      Accounting  2004 Charade Rd       98199  Seattle
#
#                               country
# employee_id
# 100          United States of America
# 101          United States of America
# 102          United States of America
# 108          United States of America
# 109          United States of America
# 110          United States of America
# 111          United States of America
# 112          United States of America
# 113          United States of America
# 114          United States of America
# 115          United States of America
# 116          United States of America
# 117          United States of America
# 118          United States of America
# 119          United States of America
# 200          United States of America
# 205          United States of America
# 206          United States of America

# %% [markdown]
# We can use several conditions for filtering (as in NumPy) and to connect them together we need `and`, `or` operators, but as with NumPy we have to use:
# - `and` -> `&`
# - `or` -> `|`
#
# Also, each condition has to be surrounded with `()`.

# %%
emps[(emps.city == 'Seattle') & (emps.job_title == 'Purchasing Clerk')]
# Out:
#             first_name   last_name         job_title  salary  hire_date  \
# employee_id
# 115          Alexander        Khoo  Purchasing Clerk    3100 2005-05-18
# 116             Shelli       Baida  Purchasing Clerk    2900 2007-12-24
# 117              Sigal      Tobias  Purchasing Clerk    2800 2007-07-24
# 118                Guy      Himuro  Purchasing Clerk    2600 2008-11-15
# 119              Karen  Colmenares  Purchasing Clerk    2500 2009-08-10
#
#             department_name          address postal_code     city  \
# employee_id
# 115              Purchasing  2004 Charade Rd       98199  Seattle
# 116              Purchasing  2004 Charade Rd       98199  Seattle
# 117              Purchasing  2004 Charade Rd       98199  Seattle
# 118              Purchasing  2004 Charade Rd       98199  Seattle
# 119              Purchasing  2004 Charade Rd       98199  Seattle
#
#                               country
# employee_id
# 115          United States of America
# 116          United States of America
# 117          United States of America
# 118          United States of America
# 119          United States of America

# %% [markdown]
# ## Data modification
#
# for example:
# - changing existing data, like particular cells or whole columns
# - adding new columns based on the data we have

# %%
emps['salary'] * 12
# Out:
# employee_id
# 100    288000
# 101    204000
# 102    204000
# 103    108000
# 104     72000
#         ...
# 202     72000
# 203     78000
# 204    120000
# 205    144000
# 206     99600
# Name: salary, Length: 107, dtype: int64

# %%
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.sort_values.html
emps['salary_per_year'] = emps['salary'] * 12
emps.sort_values('salary_per_year', ascending=False)
# Out:
#             first_name   last_name                      job_title  salary  \
# employee_id
# 100             Steven        King                      President   24000
# 102                Lex     De Haan  Administration Vice President   17000
# 101              Neena     Kochhar  Administration Vice President   17000
# 145               John     Russell                  Sales Manager   14000
# 146              Karen    Partners                  Sales Manager   13500
# ...                ...         ...                            ...     ...
# 127              James      Landry                    Stock Clerk    2400
# 135                 Ki         Gee                    Stock Clerk    2400
# 128             Steven      Markle                    Stock Clerk    2200
# 136              Hazel  Philtanker                    Stock Clerk    2200
# 132                 TJ       Olson                    Stock Clerk    2100
#
#              hire_date department_name  \
# employee_id
# 100         1997-06-17       Executive
# 102         2003-01-13       Executive
# 101         1999-09-21       Executive
# 145         2006-10-01           Sales
# 146         2007-01-05           Sales
# ...                ...             ...
# 127         2009-01-14        Shipping
# 135         2009-12-12        Shipping
# 128         2010-03-08        Shipping
# 136         2011-02-06        Shipping
# 132         2009-04-10        Shipping
#
#                                               address postal_code  \
# employee_id
# 100                                   2004 Charade Rd       98199
# 102                                   2004 Charade Rd       98199
# 101                                   2004 Charade Rd       98199
# 145          Magdalen Centre, The Oxford Science Park     OX9 9ZB
# 146          Magdalen Centre, The Oxford Science Park     OX9 9ZB
# ...                                               ...         ...
# 127                               2011 Interiors Blvd       99236
# 135                               2011 Interiors Blvd       99236
# 128                               2011 Interiors Blvd       99236
# 136                               2011 Interiors Blvd       99236
# 132                               2011 Interiors Blvd       99236
#
#                             city                   country  salary_per_year
# employee_id
# 100                      Seattle  United States of America           288000
# 102                      Seattle  United States of America           204000
# 101                      Seattle  United States of America           204000
# 145                       Oxford            United Kingdom           168000
# 146                       Oxford            United Kingdom           162000
# ...                          ...                       ...              ...
# 127          South San Francisco  United States of America            28800
# 135          South San Francisco  United States of America            28800
# 128          South San Francisco  United States of America            26400
# 136          South San Francisco  United States of America            26400
# 132          South San Francisco  United States of America            25200
#
# [107 rows x 11 columns]

# %%
emps
# Out:
#             first_name last_name                        job_title  salary  \
# employee_id
# 100             Steven      King                        President   24000
# 101              Neena   Kochhar    Administration Vice President   17000
# 102                Lex   De Haan    Administration Vice President   17000
# 103          Alexander    Hunold                       Programmer    9000
# 104              Bruce     Ernst                       Programmer    6000
# ...                ...       ...                              ...     ...
# 202                Pat       Fay         Marketing Representative    6000
# 203              Susan    Mavris   Human Resources Representative    6500
# 204            Hermann      Baer  Public Relations Representative   10000
# 205            Shelley   Higgins               Accounting Manager   12000
# 206            William     Gietz                Public Accountant    8300
#
#              hire_date   department_name                address postal_code  \
# employee_id
# 100         1997-06-17         Executive        2004 Charade Rd       98199
# 101         1999-09-21         Executive        2004 Charade Rd       98199
# 102         2003-01-13         Executive        2004 Charade Rd       98199
# 103         2000-01-03                IT    2014 Jabberwocky Rd       26192
# 104         2001-05-21                IT    2014 Jabberwocky Rd       26192
# ...                ...               ...                    ...         ...
# 202         2007-08-17         Marketing        147 Spadina Ave     M5V 2L7
# 203         2004-06-07   Human Resources         8204 Arthur St         NaN
# 204         2004-06-07  Public Relations  Schwanthalerstr. 7031       80925
# 205         2004-06-07        Accounting        2004 Charade Rd       98199
# 206         2004-06-07        Accounting        2004 Charade Rd       98199
#
#                   city                   country  salary_per_year
# employee_id
# 100            Seattle  United States of America           288000
# 101            Seattle  United States of America           204000
# 102            Seattle  United States of America           204000
# 103          Southlake  United States of America           108000
# 104          Southlake  United States of America            72000
# ...                ...                       ...              ...
# 202            Toronto                    Canada            72000
# 203             London            United Kingdom            78000
# 204             Munich                   Germany           120000
# 205            Seattle  United States of America           144000
# 206            Seattle  United States of America            99600
#
# [107 rows x 11 columns]

# %% [markdown]
# We can modify particular rows or cells using `iloc` and `loc` methods.

# %%
emps.iloc[0, 0] = 'John'
emps.loc[100, 'last_name'] = 'Doe'

# %%
emps
# Out:
#             first_name last_name                        job_title  salary  \
# employee_id
# 100               John       Doe                        President   24000
# 101              Neena   Kochhar    Administration Vice President   17000
# 102                Lex   De Haan    Administration Vice President   17000
# 103          Alexander    Hunold                       Programmer    9000
# 104              Bruce     Ernst                       Programmer    6000
# ...                ...       ...                              ...     ...
# 202                Pat       Fay         Marketing Representative    6000
# 203              Susan    Mavris   Human Resources Representative    6500
# 204            Hermann      Baer  Public Relations Representative   10000
# 205            Shelley   Higgins               Accounting Manager   12000
# 206            William     Gietz                Public Accountant    8300
#
#              hire_date   department_name                address postal_code  \
# employee_id
# 100         1997-06-17         Executive        2004 Charade Rd       98199
# 101         1999-09-21         Executive        2004 Charade Rd       98199
# 102         2003-01-13         Executive        2004 Charade Rd       98199
# 103         2000-01-03                IT    2014 Jabberwocky Rd       26192
# 104         2001-05-21                IT    2014 Jabberwocky Rd       26192
# ...                ...               ...                    ...         ...
# 202         2007-08-17         Marketing        147 Spadina Ave     M5V 2L7
# 203         2004-06-07   Human Resources         8204 Arthur St         NaN
# 204         2004-06-07  Public Relations  Schwanthalerstr. 7031       80925
# 205         2004-06-07        Accounting        2004 Charade Rd       98199
# 206         2004-06-07        Accounting        2004 Charade Rd       98199
#
#                   city                   country  salary_per_year
# employee_id
# 100            Seattle  United States of America           288000
# 101            Seattle  United States of America           204000
# 102            Seattle  United States of America           204000
# 103          Southlake  United States of America           108000
# 104          Southlake  United States of America            72000
# ...                ...                       ...              ...
# 202            Toronto                    Canada            72000
# 203             London            United Kingdom            78000
# 204             Munich                   Germany           120000
# 205            Seattle  United States of America           144000
# 206            Seattle  United States of America            99600
#
# [107 rows x 11 columns]

# %% [markdown]
# To remove/delete column from our DataFrame we can use [`.drop()`](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.drop.html) method. By default when dropping a column I'm getting a copy of a DataFrame without this column or columns. To modify the original DataFrame I have to `.drop(..., inplace=True)`.

# %%
emps.drop(columns=['salary_per_year'])
# Out:
#             first_name last_name                        job_title  salary  \
# employee_id
# 100               John       Doe                        President   24000
# 101              Neena   Kochhar    Administration Vice President   17000
# 102                Lex   De Haan    Administration Vice President   17000
# 103          Alexander    Hunold                       Programmer    9000
# 104              Bruce     Ernst                       Programmer    6000
# ...                ...       ...                              ...     ...
# 202                Pat       Fay         Marketing Representative    6000
# 203              Susan    Mavris   Human Resources Representative    6500
# 204            Hermann      Baer  Public Relations Representative   10000
# 205            Shelley   Higgins               Accounting Manager   12000
# 206            William     Gietz                Public Accountant    8300
#
#              hire_date   department_name                address postal_code  \
# employee_id
# 100         1997-06-17         Executive        2004 Charade Rd       98199
# 101         1999-09-21         Executive        2004 Charade Rd       98199
# 102         2003-01-13         Executive        2004 Charade Rd       98199
# 103         2000-01-03                IT    2014 Jabberwocky Rd       26192
# 104         2001-05-21                IT    2014 Jabberwocky Rd       26192
# ...                ...               ...                    ...         ...
# 202         2007-08-17         Marketing        147 Spadina Ave     M5V 2L7
# 203         2004-06-07   Human Resources         8204 Arthur St         NaN
# 204         2004-06-07  Public Relations  Schwanthalerstr. 7031       80925
# 205         2004-06-07        Accounting        2004 Charade Rd       98199
# 206         2004-06-07        Accounting        2004 Charade Rd       98199
#
#                   city                   country
# employee_id
# 100            Seattle  United States of America
# 101            Seattle  United States of America
# 102            Seattle  United States of America
# 103          Southlake  United States of America
# 104          Southlake  United States of America
# ...                ...                       ...
# 202            Toronto                    Canada
# 203             London            United Kingdom
# 204             Munich                   Germany
# 205            Seattle  United States of America
# 206            Seattle  United States of America
#
# [107 rows x 10 columns]

# %%
emps
# Out:
#             first_name last_name                        job_title  salary  \
# employee_id
# 100               John       Doe                        President   24000
# 101              Neena   Kochhar    Administration Vice President   17000
# 102                Lex   De Haan    Administration Vice President   17000
# 103          Alexander    Hunold                       Programmer    9000
# 104              Bruce     Ernst                       Programmer    6000
# ...                ...       ...                              ...     ...
# 202                Pat       Fay         Marketing Representative    6000
# 203              Susan    Mavris   Human Resources Representative    6500
# 204            Hermann      Baer  Public Relations Representative   10000
# 205            Shelley   Higgins               Accounting Manager   12000
# 206            William     Gietz                Public Accountant    8300
#
#              hire_date   department_name                address postal_code  \
# employee_id
# 100         1997-06-17         Executive        2004 Charade Rd       98199
# 101         1999-09-21         Executive        2004 Charade Rd       98199
# 102         2003-01-13         Executive        2004 Charade Rd       98199
# 103         2000-01-03                IT    2014 Jabberwocky Rd       26192
# 104         2001-05-21                IT    2014 Jabberwocky Rd       26192
# ...                ...               ...                    ...         ...
# 202         2007-08-17         Marketing        147 Spadina Ave     M5V 2L7
# 203         2004-06-07   Human Resources         8204 Arthur St         NaN
# 204         2004-06-07  Public Relations  Schwanthalerstr. 7031       80925
# 205         2004-06-07        Accounting        2004 Charade Rd       98199
# 206         2004-06-07        Accounting        2004 Charade Rd       98199
#
#                   city                   country  salary_per_year
# employee_id
# 100            Seattle  United States of America           288000
# 101            Seattle  United States of America           204000
# 102            Seattle  United States of America           204000
# 103          Southlake  United States of America           108000
# 104          Southlake  United States of America            72000
# ...                ...                       ...              ...
# 202            Toronto                    Canada            72000
# 203             London            United Kingdom            78000
# 204             Munich                   Germany           120000
# 205            Seattle  United States of America           144000
# 206            Seattle  United States of America            99600
#
# [107 rows x 11 columns]

# %% [markdown]
# ### Accessors
#
# https://pandas.pydata.org/docs/reference/api/pandas.Series.str.upper.html

# %%
emps.city.unique()
# Out:
# array(['Seattle', 'Southlake', 'South San Francisco', 'Oxford', nan,
#        'Toronto', 'London', 'Munich'], dtype=object)

# %%
emps.city.str.upper()
# Out:
# employee_id
# 100      SEATTLE
# 101      SEATTLE
# 102      SEATTLE
# 103    SOUTHLAKE
# 104    SOUTHLAKE
#          ...
# 202      TORONTO
# 203       LONDON
# 204       MUNICH
# 205      SEATTLE
# 206      SEATTLE
# Name: city, Length: 107, dtype: object

# %%
emps.city.str.lower()
# Out:
# employee_id
# 100      seattle
# 101      seattle
# 102      seattle
# 103    southlake
# 104    southlake
#          ...
# 202      toronto
# 203       london
# 204       munich
# 205      seattle
# 206      seattle
# Name: city, Length: 107, dtype: object

# %%
emps.hire_date.dt.year
# Out:
# employee_id
# 100    1997
# 101    1999
# 102    2003
# 103    2000
# 104    2001
#        ...
# 202    2007
# 203    2004
# 204    2004
# 205    2004
# 206    2004
# Name: hire_date, Length: 107, dtype: int64

# %%
emps[emps.hire_date.dt.year.isin([2004])]
# Out:
#             first_name  last_name                        job_title  salary  \
# employee_id
# 108              Nancy  Greenberg                  Finance Manager   12000
# 109             Daniel     Faviet                       Accountant    9000
# 114                Den   Raphaely               Purchasing Manager   11000
# 203              Susan     Mavris   Human Resources Representative    6500
# 204            Hermann       Baer  Public Relations Representative   10000
# 205            Shelley    Higgins               Accounting Manager   12000
# 206            William      Gietz                Public Accountant    8300
#
#              hire_date   department_name                address postal_code  \
# employee_id
# 108         2004-08-17           Finance        2004 Charade Rd       98199
# 109         2004-08-16           Finance        2004 Charade Rd       98199
# 114         2004-12-07        Purchasing        2004 Charade Rd       98199
# 203         2004-06-07   Human Resources         8204 Arthur St         NaN
# 204         2004-06-07  Public Relations  Schwanthalerstr. 7031       80925
# 205         2004-06-07        Accounting        2004 Charade Rd       98199
# 206         2004-06-07        Accounting        2004 Charade Rd       98199
#
#                 city                   country  salary_per_year
# employee_id
# 108          Seattle  United States of America           144000
# 109          Seattle  United States of America           108000
# 114          Seattle  United States of America           132000
# 203           London            United Kingdom            78000
# 204           Munich                   Germany           120000
# 205          Seattle  United States of America           144000
# 206          Seattle  United States of America            99600

# %%
emps[
    (emps.hire_date.dt.year >= 2000) & (emps.hire_date.dt.year <= 2005)
]
# Out:
#             first_name  last_name                        job_title  salary  \
# employee_id
# 102                Lex    De Haan    Administration Vice President   17000
# 103          Alexander     Hunold                       Programmer    9000
# 104              Bruce      Ernst                       Programmer    6000
# 108              Nancy  Greenberg                  Finance Manager   12000
# 109             Daniel     Faviet                       Accountant    9000
# 114                Den   Raphaely               Purchasing Manager   11000
# 115          Alexander       Khoo                 Purchasing Clerk    3100
# 122              Payam   Kaufling                    Stock Manager    7900
# 137             Renske     Ladwig                      Stock Clerk    3600
# 141             Trenna       Rajs                      Stock Clerk    3500
# 149              Eleni    Zlotkey                    Sales Manager   10500
# 165              David        Lee             Sales Representative    6800
# 166             Sundar       Ande             Sales Representative    6400
# 167               Amit      Banda             Sales Representative    6200
# 183             Girard      Geoni                   Shipping Clerk    2800
# 203              Susan     Mavris   Human Resources Representative    6500
# 204            Hermann       Baer  Public Relations Representative   10000
# 205            Shelley    Higgins               Accounting Manager   12000
# 206            William      Gietz                Public Accountant    8300
#
#              hire_date   department_name  \
# employee_id
# 102         2003-01-13         Executive
# 103         2000-01-03                IT
# 104         2001-05-21                IT
# 108         2004-08-17           Finance
# 109         2004-08-16           Finance
# 114         2004-12-07        Purchasing
# 115         2005-05-18        Purchasing
# 122         2005-05-01          Shipping
# 137         2005-07-14          Shipping
# 141         2005-10-17          Shipping
# 149         2000-01-29             Sales
# 165         2000-02-23             Sales
# 166         2000-03-24             Sales
# 167         2000-04-21             Sales
# 183         2000-02-03          Shipping
# 203         2004-06-07   Human Resources
# 204         2004-06-07  Public Relations
# 205         2004-06-07        Accounting
# 206         2004-06-07        Accounting
#
#                                               address postal_code  \
# employee_id
# 102                                   2004 Charade Rd       98199
# 103                               2014 Jabberwocky Rd       26192
# 104                               2014 Jabberwocky Rd       26192
# 108                                   2004 Charade Rd       98199
# 109                                   2004 Charade Rd       98199
# 114                                   2004 Charade Rd       98199
# 115                                   2004 Charade Rd       98199
# 122                               2011 Interiors Blvd       99236
# 137                               2011 Interiors Blvd       99236
# 141                               2011 Interiors Blvd       99236
# 149          Magdalen Centre, The Oxford Science Park     OX9 9ZB
# 165          Magdalen Centre, The Oxford Science Park     OX9 9ZB
# 166          Magdalen Centre, The Oxford Science Park     OX9 9ZB
# 167          Magdalen Centre, The Oxford Science Park     OX9 9ZB
# 183                               2011 Interiors Blvd       99236
# 203                                    8204 Arthur St         NaN
# 204                             Schwanthalerstr. 7031       80925
# 205                                   2004 Charade Rd       98199
# 206                                   2004 Charade Rd       98199
#
#                             city                   country  salary_per_year
# employee_id
# 102                      Seattle  United States of America           204000
# 103                    Southlake  United States of America           108000
# 104                    Southlake  United States of America            72000
# 108                      Seattle  United States of America           144000
# 109                      Seattle  United States of America           108000
# 114                      Seattle  United States of America           132000
# 115                      Seattle  United States of America            37200
# 122          South San Francisco  United States of America            94800
# 137          South San Francisco  United States of America            43200
# 141          South San Francisco  United States of America            42000
# 149                       Oxford            United Kingdom           126000
# 165                       Oxford            United Kingdom            81600
# 166                       Oxford            United Kingdom            76800
# 167                       Oxford            United Kingdom            74400
# 183          South San Francisco  United States of America            33600
# 203                       London            United Kingdom            78000
# 204                       Munich                   Germany           120000
# 205                      Seattle  United States of America           144000
# 206                      Seattle  United States of America            99600
