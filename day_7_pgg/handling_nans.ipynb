# %%
import pandas as pd
import numpy as np

# %%
url = 'https://github.com/piotrgradzinski/dap_20230114/raw/main/day_7_pgg/employees_ext.csv'
emps = pd.read_csv(url, index_col='employee_id', delimiter=',')
emps
# Out:
#             first_name last_name     email  phone_number   hire_date  \
# employee_id
# 100             Steven      King     SKING  515.123.4567  1987-06-17
# 101              Neena   Kochhar  NKOCHHAR  515.123.4568  1989-09-21
# 102                Lex   De Haan   LDEHAAN  515.123.4569  1993-01-13
# 103          Alexander    Hunold   AHUNOLD  590.423.4567  1990-01-03
# 104              Bruce     Ernst    BERNST  590.423.4568  1991-05-21
# ...                ...       ...       ...           ...         ...
# 202                Pat       Fay      PFAY  603.123.6666  1997-08-17
# 203              Susan    Mavris   SMAVRIS  515.123.7777  1994-06-07
# 204            Hermann      Baer     HBAER  515.123.8888  1994-06-07
# 205            Shelley   Higgins  SHIGGINS  515.123.8080  1994-06-07
# 206            William     Gietz    WGIETZ  515.123.8181  1994-06-07
#
#                  job_id   salary  commission_pct  manager_id  department_id
# employee_id
# ...

# %%
emps.sample(15)
# Out:
#             first_name   last_name     email        phone_number   hire_date  \
# employee_id
# 143            Randall       Matos    RMATOS        650.121.2874  1998-03-15
# 148             Gerald   Cambrault  GCAMBRAU  011.44.1344.619268  1999-10-15
# 188              Kelly       Chung    KCHUNG        650.505.1876  1997-06-14
# 127              James      Landry   JLANDRY        650.124.1334  1999-01-14
# 119              Karen  Colmenares  KCOLMENA        515.127.4566  1999-08-10
# 146              Karen    Partners  KPARTNER  011.44.1344.467268  1997-01-05
# 141             Trenna        Rajs     TRAJS        650.121.8009  1995-10-17
# 149              Eleni     Zlotkey  EZLOTKEY  011.44.1344.429018  2000-01-29
# 154            Nanette   Cambrault  NCAMBRAU  011.44.1344.987668  1998-12-09
# 182             Martha    Sullivan  MSULLIVA        650.507.9878  1999-06-21
# 177               Jack  Livingston  JLIVINGS  011.44.1644.429264  1998-04-23
# ...

# %%
emps
# Out:
#             first_name last_name     email  phone_number   hire_date  \
# employee_id
# 100             Steven      King     SKING  515.123.4567  1987-06-17
# 101              Neena   Kochhar  NKOCHHAR  515.123.4568  1989-09-21
# 102                Lex   De Haan   LDEHAAN  515.123.4569  1993-01-13
# 103          Alexander    Hunold   AHUNOLD  590.423.4567  1990-01-03
# 104              Bruce     Ernst    BERNST  590.423.4568  1991-05-21
# ...                ...       ...       ...           ...         ...
# 202                Pat       Fay      PFAY  603.123.6666  1997-08-17
# 203              Susan    Mavris   SMAVRIS  515.123.7777  1994-06-07
# 204            Hermann      Baer     HBAER  515.123.8888  1994-06-07
# 205            Shelley   Higgins  SHIGGINS  515.123.8080  1994-06-07
# 206            William     Gietz    WGIETZ  515.123.8181  1994-06-07
#
#                  job_id   salary  commission_pct  manager_id  department_id
# employee_id
# ...

# %%
emps.isnull()
# Out:
#              first_name  last_name  email  phone_number  hire_date  job_id  \
# employee_id
# 100               False      False  False         False      False   False
# 101               False      False  False         False      False   False
# 102               False      False  False         False      False   False
# 103               False      False  False         False      False   False
# 104               False      False  False         False      False   False
# ...                 ...        ...    ...           ...        ...     ...
# 202               False      False  False         False      False   False
# 203               False      False  False         False      False   False
# 204               False      False  False         False      False   False
# 205               False      False  False         False      False   False
# 206               False      False  False         False      False   False
#
# ...

# %%
emps.isnull().any()
# Out:
# first_name        False
# last_name         False
# email             False
# phone_number      False
# hire_date         False
# job_id            False
# salary            False
# commission_pct     True
# manager_id         True
# department_id      True
# dtype: bool

# %%
emps.isnull().any(axis=0)
# Out:
# first_name        False
# last_name         False
# email             False
# phone_number      False
# hire_date         False
# job_id            False
# salary            False
# commission_pct     True
# manager_id         True
# department_id      True
# dtype: bool

# %%
emps.isnull().any(axis=1)
# Out:
# employee_id
# 100    True
# 101    True
# 102    True
# 103    True
# 104    True
#        ...
# 202    True
# 203    True
# 204    True
# 205    True
# 206    True
# Length: 107, dtype: bool

# %%
# one way to find rows which contain NaN
emps[emps.isnull().any(axis=1)]
# Out:
#             first_name last_name     email  phone_number   hire_date  \
# employee_id
# 100             Steven      King     SKING  515.123.4567  1987-06-17
# 101              Neena   Kochhar  NKOCHHAR  515.123.4568  1989-09-21
# 102                Lex   De Haan   LDEHAAN  515.123.4569  1993-01-13
# 103          Alexander    Hunold   AHUNOLD  590.423.4567  1990-01-03
# 104              Bruce     Ernst    BERNST  590.423.4568  1991-05-21
# ...                ...       ...       ...           ...         ...
# 202                Pat       Fay      PFAY  603.123.6666  1997-08-17
# 203              Susan    Mavris   SMAVRIS  515.123.7777  1994-06-07
# 204            Hermann      Baer     HBAER  515.123.8888  1994-06-07
# 205            Shelley   Higgins  SHIGGINS  515.123.8080  1994-06-07
# 206            William     Gietz    WGIETZ  515.123.8181  1994-06-07
#
#                  job_id   salary  commission_pct  manager_id  department_id
# employee_id
# ...

# %%
# one way to find rows which doesn't contain NaN
emps[~emps.isnull().any(axis=1)]
# Out:
#               first_name   last_name     email        phone_number  \
# employee_id
# 145                 John     Russell   JRUSSEL  011.44.1344.429268
# 146                Karen    Partners  KPARTNER  011.44.1344.467268
# 147              Alberto   Errazuriz  AERRAZUR  011.44.1344.429278
# 148               Gerald   Cambrault  GCAMBRAU  011.44.1344.619268
# 149                Eleni     Zlotkey  EZLOTKEY  011.44.1344.429018
# 150                Peter      Tucker   PTUCKER  011.44.1344.129268
# 151                David   Bernstein  DBERNSTE  011.44.1344.345268
# 152                Peter        Hall     PHALL  011.44.1344.478968
# 153          Christopher       Olsen    COLSEN  011.44.1344.498718
# 154              Nanette   Cambrault  NCAMBRAU  011.44.1344.987668
# 155               Oliver     Tuvault  OTUVAULT  011.44.1344.486508
# 156              Janette        King     JKING  011.44.1345.429268
# 157              Patrick       Sully    PSULLY  011.44.1345.929268
# ...

# %% [markdown]
# # How we can replace NaN values with different ones

# %% [markdown]
# ## `replace`

# %%
emps.replace(np.NaN, 0.0)
# Out:
#             first_name last_name     email  phone_number   hire_date  \
# employee_id
# 100             Steven      King     SKING  515.123.4567  1987-06-17
# 101              Neena   Kochhar  NKOCHHAR  515.123.4568  1989-09-21
# 102                Lex   De Haan   LDEHAAN  515.123.4569  1993-01-13
# 103          Alexander    Hunold   AHUNOLD  590.423.4567  1990-01-03
# 104              Bruce     Ernst    BERNST  590.423.4568  1991-05-21
# ...                ...       ...       ...           ...         ...
# 202                Pat       Fay      PFAY  603.123.6666  1997-08-17
# 203              Susan    Mavris   SMAVRIS  515.123.7777  1994-06-07
# 204            Hermann      Baer     HBAER  515.123.8888  1994-06-07
# 205            Shelley   Higgins  SHIGGINS  515.123.8080  1994-06-07
# 206            William     Gietz    WGIETZ  515.123.8181  1994-06-07
#
#                  job_id   salary  commission_pct  manager_id  department_id
# employee_id
# ...

# %% [markdown]
# ## `fillna`
#
# [`.fillna()`](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.fillna.html) - replaces missing values (like `NaN` and `NaT`) by given value.

# %%
emps.fillna(0.0)
# Out:
#             first_name last_name     email  phone_number   hire_date  \
# employee_id
# 100             Steven      King     SKING  515.123.4567  1987-06-17
# 101              Neena   Kochhar  NKOCHHAR  515.123.4568  1989-09-21
# 102                Lex   De Haan   LDEHAAN  515.123.4569  1993-01-13
# 103          Alexander    Hunold   AHUNOLD  590.423.4567  1990-01-03
# 104              Bruce     Ernst    BERNST  590.423.4568  1991-05-21
# ...                ...       ...       ...           ...         ...
# 202                Pat       Fay      PFAY  603.123.6666  1997-08-17
# 203              Susan    Mavris   SMAVRIS  515.123.7777  1994-06-07
# 204            Hermann      Baer     HBAER  515.123.8888  1994-06-07
# 205            Shelley   Higgins  SHIGGINS  515.123.8080  1994-06-07
# 206            William     Gietz    WGIETZ  515.123.8181  1994-06-07
#
#                  job_id   salary  commission_pct  manager_id  department_id
# employee_id
# ...

# %%
emps.fillna({'manager_id': 0, 'commission_pct': 0.99})
# Out:
#             first_name last_name     email  phone_number   hire_date  \
# employee_id
# 100             Steven      King     SKING  515.123.4567  1987-06-17
# 101              Neena   Kochhar  NKOCHHAR  515.123.4568  1989-09-21
# 102                Lex   De Haan   LDEHAAN  515.123.4569  1993-01-13
# 103          Alexander    Hunold   AHUNOLD  590.423.4567  1990-01-03
# 104              Bruce     Ernst    BERNST  590.423.4568  1991-05-21
# ...                ...       ...       ...           ...         ...
# 202                Pat       Fay      PFAY  603.123.6666  1997-08-17
# 203              Susan    Mavris   SMAVRIS  515.123.7777  1994-06-07
# 204            Hermann      Baer     HBAER  515.123.8888  1994-06-07
# 205            Shelley   Higgins  SHIGGINS  515.123.8080  1994-06-07
# 206            William     Gietz    WGIETZ  515.123.8181  1994-06-07
#
#                  job_id   salary  commission_pct  manager_id  department_id
# employee_id
# ...

# %%
emps.sort_values(['first_name', 'last_name'], inplace=True)
emps.head(5)
# Out:
#             first_name  last_name     email        phone_number   hire_date  \
# employee_id
# 121               Adam      Fripp    AFRIPP        650.123.2234  1997-04-10
# 196              Alana      Walsh    AWALSH        650.507.9811  1998-04-24
# 147            Alberto  Errazuriz  AERRAZUR  011.44.1344.429278  1997-03-10
# 103          Alexander     Hunold   AHUNOLD        590.423.4567  1990-01-03
# 115          Alexander       Khoo     AKHOO        515.127.4562  1995-05-18
#
#                job_id   salary  commission_pct  manager_id  department_id
# employee_id
# 121            ST_MAN   8200.0             NaN       100.0           50.0
# 196          SH_CLERK   3100.0             NaN       124.0           50.0
# 147            SA_MAN  12000.0             0.3       100.0           80.0
# 103           IT_PROG   9000.0             NaN       102.0           60.0
# 115          PU_CLERK   3100.0             NaN       114.0           30.0

# %%
# do the field contaning NaN we will put prevoius non-NaN value
emps.fillna(method='ffill').head(20)
# Out:
#               first_name  last_name     email        phone_number   hire_date  \
# employee_id
# 121                 Adam      Fripp    AFRIPP        650.123.2234  1997-04-10
# 196                Alana      Walsh    AWALSH        650.507.9811  1998-04-24
# 147              Alberto  Errazuriz  AERRAZUR  011.44.1344.429278  1997-03-10
# 103            Alexander     Hunold   AHUNOLD        590.423.4567  1990-01-03
# 115            Alexander       Khoo     AKHOO        515.127.4562  1995-05-18
# 185               Alexis       Bull     ABULL        650.509.2876  1997-02-20
# 158                Allan     McEwen   AMCEWEN  011.44.1345.829268  1996-08-01
# 175               Alyssa     Hutton   AHUTTON  011.44.1644.429266  1997-03-19
# 167                 Amit      Banda    ABANDA  011.44.1346.729268  2000-04-21
# 187              Anthony     Cabrio   ACABRIO        650.509.4876  1999-02-07
# 193              Britney    Everett  BEVERETT        650.501.2876  1997-03-03
# ...

# %%
# to the field containg NaN we will put first non-NaN value from later value
emps.fillna(method='bfill').head(20)
# Out:
#               first_name  last_name     email        phone_number   hire_date  \
# employee_id
# 121                 Adam      Fripp    AFRIPP        650.123.2234  1997-04-10
# 196                Alana      Walsh    AWALSH        650.507.9811  1998-04-24
# 147              Alberto  Errazuriz  AERRAZUR  011.44.1344.429278  1997-03-10
# 103            Alexander     Hunold   AHUNOLD        590.423.4567  1990-01-03
# 115            Alexander       Khoo     AKHOO        515.127.4562  1995-05-18
# 185               Alexis       Bull     ABULL        650.509.2876  1997-02-20
# 158                Allan     McEwen   AMCEWEN  011.44.1345.829268  1996-08-01
# 175               Alyssa     Hutton   AHUTTON  011.44.1644.429266  1997-03-19
# 167                 Amit      Banda    ABANDA  011.44.1346.729268  2000-04-21
# 187              Anthony     Cabrio   ACABRIO        650.509.4876  1999-02-07
# 193              Britney    Everett  BEVERETT        650.501.2876  1997-03-03
# ...

# %%
emps.fillna(method='bfill', limit=1).head(20)
# Out:
#               first_name  last_name     email        phone_number   hire_date  \
# employee_id
# 121                 Adam      Fripp    AFRIPP        650.123.2234  1997-04-10
# 196                Alana      Walsh    AWALSH        650.507.9811  1998-04-24
# 147              Alberto  Errazuriz  AERRAZUR  011.44.1344.429278  1997-03-10
# 103            Alexander     Hunold   AHUNOLD        590.423.4567  1990-01-03
# 115            Alexander       Khoo     AKHOO        515.127.4562  1995-05-18
# 185               Alexis       Bull     ABULL        650.509.2876  1997-02-20
# 158                Allan     McEwen   AMCEWEN  011.44.1345.829268  1996-08-01
# 175               Alyssa     Hutton   AHUTTON  011.44.1644.429266  1997-03-19
# 167                 Amit      Banda    ABANDA  011.44.1346.729268  2000-04-21
# 187              Anthony     Cabrio   ACABRIO        650.509.4876  1999-02-07
# 193              Britney    Everett  BEVERETT        650.501.2876  1997-03-03
# ...

# %%
emps.commission_pct.fillna(method='ffill').head(20)
# Out:
# employee_id
# 121     NaN
# 196     NaN
# 147    0.30
# 103    0.30
# 115    0.30
# 185    0.30
# 158    0.35
# 175    0.25
# 167    0.10
# 187    0.10
# 193    0.10
# 104    0.10
# 179    0.10
# 153    0.20
# 162    0.25
# 142    0.25
# 109    0.25
# 163    0.15
# 105    0.15
# 151    0.25
# Name: commission_pct, dtype: float64

# %% [markdown]
# ## Why we should check and handle `NaN`s in our data?
#
# - it has an impact on many operations we will be doing on our data and may mess with then resulting that we won't have proper results.

# %%
emps
# Out:
#             first_name  last_name     email        phone_number   hire_date  \
# employee_id
# 121               Adam      Fripp    AFRIPP        650.123.2234  1997-04-10
# 196              Alana      Walsh    AWALSH        650.507.9811  1998-04-24
# 147            Alberto  Errazuriz  AERRAZUR  011.44.1344.429278  1997-03-10
# 103          Alexander     Hunold   AHUNOLD        590.423.4567  1990-01-03
# 115          Alexander       Khoo     AKHOO        515.127.4562  1995-05-18
# ...                ...        ...       ...                 ...         ...
# 106              Valli  Pataballa  VPATABAL        590.423.4560  1998-02-05
# 195              Vance      Jones    VJONES        650.501.4876  1999-03-17
# 206            William      Gietz    WGIETZ        515.123.8181  1994-06-07
# 171            William      Smith    WSMITH  011.44.1343.629268  1999-02-23
# 180            Winston     Taylor   WTAYLOR        650.507.9876  1998-01-24
#
# ...

# %%
# mean() is calculated based on non-empty values, so empty values are not included into the calculation
emps.commission_pct.mean()
# Out:
# 0.22285714285714286

# %%
emps.commission_pct.fillna(0.0).mean()
# Out:
# 0.07289719626168224

# %%
emps.commission_pct.mean(skipna=False)
# Out:
# nan

# %%
emps.commission_pct.isna()
# Out:
# employee_id
# 121     True
# 196     True
# 147    False
# 103     True
# 115     True
#        ...
# 106     True
# 195     True
# 206     True
# 171    False
# 180     True
# Name: commission_pct, Length: 107, dtype: bool

# %%
emps.commission_pct.notna()
# Out:
# employee_id
# 121    False
# 196    False
# 147     True
# 103    False
# 115    False
#        ...
# 106    False
# 195    False
# 206    False
# 171     True
# 180    False
# Name: commission_pct, Length: 107, dtype: bool

# %%
# Employees that don't take commision
emps[emps.commission_pct.isna()]
# Out:
#             first_name  last_name     email  phone_number   hire_date  \
# employee_id
# 121               Adam      Fripp    AFRIPP  650.123.2234  1997-04-10
# 196              Alana      Walsh    AWALSH  650.507.9811  1998-04-24
# 103          Alexander     Hunold   AHUNOLD  590.423.4567  1990-01-03
# 115          Alexander       Khoo     AKHOO  515.127.4562  1995-05-18
# 185             Alexis       Bull     ABULL  650.509.2876  1997-02-20
# ...                ...        ...       ...           ...         ...
# 141             Trenna       Rajs     TRAJS  650.121.8009  1995-10-17
# 106              Valli  Pataballa  VPATABAL  590.423.4560  1998-02-05
# 195              Vance      Jones    VJONES  650.501.4876  1999-03-17
# 206            William      Gietz    WGIETZ  515.123.8181  1994-06-07
# 180            Winston     Taylor   WTAYLOR  650.507.9876  1998-01-24
#
#                  job_id  salary  commission_pct  manager_id  department_id
# employee_id
# ...

# %%
# Employees that do take commision
emps[emps.commission_pct.notna()]
# Out:
#               first_name   last_name     email        phone_number  \
# employee_id
# 147              Alberto   Errazuriz  AERRAZUR  011.44.1344.429278
# 158                Allan      McEwen   AMCEWEN  011.44.1345.829268
# 175               Alyssa      Hutton   AHUTTON  011.44.1644.429266
# 167                 Amit       Banda    ABANDA  011.44.1346.729268
# 179              Charles     Johnson  CJOHNSON  011.44.1644.429262
# 153          Christopher       Olsen    COLSEN  011.44.1344.498718
# 162                Clara     Vishney  CVISHNEY  011.44.1346.129268
# 163             Danielle      Greene   DGREENE  011.44.1346.229268
# 151                David   Bernstein  DBERNSTE  011.44.1344.345268
# 165                David         Lee      DLEE  011.44.1346.529268
# 149                Eleni     Zlotkey  EZLOTKEY  011.44.1344.429018
# 172            Elizabeth       Bates    EBATES  011.44.1343.529268
# 174                Ellen        Abel     EABEL  011.44.1644.429267
# ...

# %%
sum(emps.commission_pct.isna()), sum(emps.commission_pct.notna())
# Out:
# (72, 35)

# %%
emps.salary + emps.salary * emps.commission_pct
# Out:
# employee_id
# 121        NaN
# 196        NaN
# 147    15600.0
# 103        NaN
# 115        NaN
#         ...
# 106        NaN
# 195        NaN
# 206        NaN
# 171     8510.0
# 180        NaN
# Length: 107, dtype: float64

# %%
emps.salary + emps.salary * emps.commission_pct.fillna(0.0)
# Out:
# employee_id
# 121     8200.0
# 196     3100.0
# 147    15600.0
# 103     9000.0
# 115     3100.0
#         ...
# 106     4800.0
# 195     2800.0
# 206     8300.0
# 171     8510.0
# 180     3200.0
# Length: 107, dtype: float64

# %%
emps['total_salary'] = emps.salary + emps.salary * emps.commission_pct.fillna(0.0)
emps
# Out:
#             first_name  last_name     email        phone_number   hire_date  \
# employee_id
# 121               Adam      Fripp    AFRIPP        650.123.2234  1997-04-10
# 196              Alana      Walsh    AWALSH        650.507.9811  1998-04-24
# 147            Alberto  Errazuriz  AERRAZUR  011.44.1344.429278  1997-03-10
# 103          Alexander     Hunold   AHUNOLD        590.423.4567  1990-01-03
# 115          Alexander       Khoo     AKHOO        515.127.4562  1995-05-18
# ...                ...        ...       ...                 ...         ...
# 106              Valli  Pataballa  VPATABAL        590.423.4560  1998-02-05
# 195              Vance      Jones    VJONES        650.501.4876  1999-03-17
# 206            William      Gietz    WGIETZ        515.123.8181  1994-06-07
# 171            William      Smith    WSMITH  011.44.1343.629268  1999-02-23
# 180            Winston     Taylor   WTAYLOR        650.507.9876  1998-01-24
#
# ...

# %% [markdown]
# ## Removing rows containing `NaN`s
#
# If we don't want to repalce `NaN`s by something else we can always ignore that (maybe not the best option) or we can just remove all rows that contains `NaN`s from our DataFrame.
#
# For that operation we will user [`.dropna()`](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.dropna.html).

# %%
emps.dropna()  # removing all rows that in any column contain NaN value.
# Out:
#               first_name   last_name     email        phone_number  \
# employee_id
# 147              Alberto   Errazuriz  AERRAZUR  011.44.1344.429278
# 158                Allan      McEwen   AMCEWEN  011.44.1345.829268
# 175               Alyssa      Hutton   AHUTTON  011.44.1644.429266
# 167                 Amit       Banda    ABANDA  011.44.1346.729268
# 179              Charles     Johnson  CJOHNSON  011.44.1644.429262
# 153          Christopher       Olsen    COLSEN  011.44.1344.498718
# 162                Clara     Vishney  CVISHNEY  011.44.1346.129268
# 163             Danielle      Greene   DGREENE  011.44.1346.229268
# 151                David   Bernstein  DBERNSTE  011.44.1344.345268
# 165                David         Lee      DLEE  011.44.1346.529268
# 149                Eleni     Zlotkey  EZLOTKEY  011.44.1344.429018
# 172            Elizabeth       Bates    EBATES  011.44.1343.529268
# 174                Ellen        Abel     EABEL  011.44.1644.429267
# ...

# %%
emps.dropna(how='all')  # removing when all values in the row are NaN, useful when cleaning data, 'any' by default
# Out:
#             first_name  last_name     email        phone_number   hire_date  \
# employee_id
# 121               Adam      Fripp    AFRIPP        650.123.2234  1997-04-10
# 196              Alana      Walsh    AWALSH        650.507.9811  1998-04-24
# 147            Alberto  Errazuriz  AERRAZUR  011.44.1344.429278  1997-03-10
# 103          Alexander     Hunold   AHUNOLD        590.423.4567  1990-01-03
# 115          Alexander       Khoo     AKHOO        515.127.4562  1995-05-18
# ...                ...        ...       ...                 ...         ...
# 106              Valli  Pataballa  VPATABAL        590.423.4560  1998-02-05
# 195              Vance      Jones    VJONES        650.501.4876  1999-03-17
# 206            William      Gietz    WGIETZ        515.123.8181  1994-06-07
# 171            William      Smith    WSMITH  011.44.1343.629268  1999-02-23
# 180            Winston     Taylor   WTAYLOR        650.507.9876  1998-01-24
#
# ...

# %%
emps.sort_index()
# Out:
#             first_name last_name     email  phone_number   hire_date  \
# employee_id
# 100             Steven      King     SKING  515.123.4567  1987-06-17
# 101              Neena   Kochhar  NKOCHHAR  515.123.4568  1989-09-21
# 102                Lex   De Haan   LDEHAAN  515.123.4569  1993-01-13
# 103          Alexander    Hunold   AHUNOLD  590.423.4567  1990-01-03
# 104              Bruce     Ernst    BERNST  590.423.4568  1991-05-21
# ...                ...       ...       ...           ...         ...
# 202                Pat       Fay      PFAY  603.123.6666  1997-08-17
# 203              Susan    Mavris   SMAVRIS  515.123.7777  1994-06-07
# 204            Hermann      Baer     HBAER  515.123.8888  1994-06-07
# 205            Shelley   Higgins  SHIGGINS  515.123.8080  1994-06-07
# 206            William     Gietz    WGIETZ  515.123.8181  1994-06-07
#
#                  job_id   salary  commission_pct  manager_id  department_id  \
# employee_id
# ...

# %%
emps.sort_index().dropna(subset=['manager_id'])
# Out:
#             first_name last_name     email  phone_number   hire_date  \
# employee_id
# 101              Neena   Kochhar  NKOCHHAR  515.123.4568  1989-09-21
# 102                Lex   De Haan   LDEHAAN  515.123.4569  1993-01-13
# 103          Alexander    Hunold   AHUNOLD  590.423.4567  1990-01-03
# 104              Bruce     Ernst    BERNST  590.423.4568  1991-05-21
# 105              David    Austin   DAUSTIN  590.423.4569  1997-06-25
# ...                ...       ...       ...           ...         ...
# 202                Pat       Fay      PFAY  603.123.6666  1997-08-17
# 203              Susan    Mavris   SMAVRIS  515.123.7777  1994-06-07
# 204            Hermann      Baer     HBAER  515.123.8888  1994-06-07
# 205            Shelley   Higgins  SHIGGINS  515.123.8080  1994-06-07
# 206            William     Gietz    WGIETZ  515.123.8181  1994-06-07
#
#                  job_id   salary  commission_pct  manager_id  department_id  \
# employee_id
# ...
